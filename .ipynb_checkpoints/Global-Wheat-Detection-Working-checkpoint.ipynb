# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Conv2D, BatchNormalization, LeakyReLU, ReLU, MaxPool2D, Add, Dense, Dropout, Flatten, GlobalAveragePooling2D
import tensorflow.compat.v1 as tf1
from tensorflow.keras.mixed_precision import experimental as mixed_precision


import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import cv2

import numpy as np

import PIL
from PIL import Image, ImageDraw, ImageEnhance

import albumentations as albu

from tqdm.auto import tqdm

import random
random.seed(42)

from warnings import filterwarnings

# %matplotlib inline

# %%
filterwarnings('ignore')

# %%
# config = tf1.ConfigProto()
# config.gpu_options.allow_growth=True
# sess = tf1.Session(config=config)
# tf1.keras.backend.set_session(session=sess)

# %%
# gpu_options = tf1.GPUOptions(per_process_gpu_memory_fraction=0.9999)
# sess = tf1.Session(config=tf1.ConfigProto(gpu_options=gpu_options))
# tf1.keras.backend.set_session(session=sess)

# %%
policy = mixed_precision.Policy('mixed_float16')
mixed_precision.set_policy(policy)
# Out:
# WARNING:tensorflow:Mixed precision compatibility check (mixed_float16): WARNING
# Your GPU may run slowly with dtype policy mixed_float16 because it does not have compute capability of at least 7.0. Your GPU:
#   GeForce GTX 1050, compute capability 6.1
# See https://developer.nvidia.com/cuda-gpus for a list of GPUs and their compute capabilities.
# If you will use compatible GPU(s) not attached to this host, e.g. by running a multi-worker model, you can ignore this warning. This message will only be logged once

# %%
# OpenCV with GPU variable
use_GPU = False

# %%
df_train = pd.read_csv("./dataset/train.csv")
df_train.head(5)
# Out:
#     image_id  width  height                         bbox   source
# 0  b6ab77fd7   1024    1024   [834.0, 222.0, 56.0, 36.0]  usask_1
# 1  b6ab77fd7   1024    1024  [226.0, 548.0, 130.0, 58.0]  usask_1
# 2  b6ab77fd7   1024    1024  [377.0, 504.0, 74.0, 160.0]  usask_1
# 3  b6ab77fd7   1024    1024  [834.0, 95.0, 109.0, 107.0]  usask_1
# 4  b6ab77fd7   1024    1024  [26.0, 144.0, 124.0, 117.0]  usask_1

# %%
df_train.isnull().sum()
# Out:
# image_id    0
# width       0
# height      0
# bbox        0
# source      0
# dtype: int64

# %%
image_id_values = df_train["image_id"].unique()

# %%
len(image_id_values)
# Out:
# 3373

# %%
train_image_ids = image_id_values[0:3363]
val_image_ids = image_id_values[3363:3373]

# %%
def group_boxes(group):
    boundaries = group['bbox'].str.split(',', expand=True)
    boundaries[0] = boundaries[0].str.slice(start=1)
    boundaries[3] = boundaries[3].str.slice(stop=-1)
    
    return boundaries.values.astype(float)

bboxes = df_train.groupby('image_id').apply(group_boxes)

# %%
bboxes['bce2fdc4d'][:5]
# Out:
# array([[ 59.,   0., 133.,  42.],
#        [742., 839., 115.,  92.],
#        [302., 665., 117.,  95.],
#        [120., 816., 133.,  82.],
#        [424., 486., 111.,  74.]])

# %%
def load_image(image_id):
    
    global use_GPU
    if use_GPU:
        image = cv2.UMat(cv2.imread('./dataset/train/'+image_id+'.jpg'))
    else:
        image = cv2.imread('./dataset/train/'+image_id+'.jpg')
        
    if use_GPU:
        if len(cv2.UMat.get(image)) == 0:
            raise ValueError(f"Image could not be located")
    else:
        if len(image) == 0:
            raise ValueError(f"Image could not be located")
    image = cv2.resize(image, (256, 256))
    
    if use_GPU:
        return cv2.UMat.get(image)
    else:
        return image

# %%
train_pixels = {}
train_labels = {}

for image_id in tqdm(train_image_ids):
    
    train_pixels[image_id] = load_image(image_id)
    train_labels[image_id] = bboxes[image_id].copy() / 4
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3363.0), HTML(value='')))

# %%
val_pixels = {}
val_labels = {}

for image_id in tqdm(val_image_ids):
    val_pixels[image_id] = load_image(image_id)
    val_labels[image_id] = bboxes[image_id].copy() / 4
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))

# %%
type(train_pixels['b6ab77fd7'])
# Out:
# numpy.ndarray

# %%
len(train_labels['b6ab77fd7'])
# Out:
# 47

# %%
def draw_bboxes(image_id, bboxes, source='train'):
    if use_GPU:
        image = cv2.UMat(cv2.imread('./dataset/'+source+'/'+image_id+'.jpg'))
    else:
        image = cv2.imread('./dataset/'+source+'/'+image_id+'.jpg')
    image = cv2.resize(image, (256, 256))
    
#     cv2.imshow('image', image)
#     cv2.waitKey()
#     cv2.destroyAllWindows()
    
    for bbox in bboxes:
        image = draw_bbox(image, bbox)
        
    return image
def draw_bbox(image, bbox):
    x, y, w, h = bbox
    image = cv2.rectangle(image,
                          (int(x), int(y)),
                          (int(x+w), int(y+h)),
                          (225,0,0), 
                          1)
    return image

# %%
def show_images(image_ids, bboxes, source='train'):
    pixels = []
    global use_GPU
    
    for image_id in image_ids:
        pixels.append(
            draw_bboxes(image_id, bboxes[image_id], source)
        )
        
    num_of_images = len(image_ids)
    fig, axes = plt.subplots(1, num_of_images, figsize=(10*num_of_images, 10*num_of_images))
    
    for i, image_pixels in enumerate(pixels):
        if use_GPU:
            axes[i].imshow(cv2.UMat.get(image_pixels))
        else:
            axes[i].imshow(image_pixels)
    #plt.show()

# %% [markdown]
# # Images with Bounding Boxes

# %%
# %%time
show_images((train_image_ids[100:102]),(train_labels))
# Out:
# CPU times: user 57.9 ms, sys: 178 µs, total: 58.1 ms
# Wall time: 56.1 ms

# %%
def draw_grid_lines(image_id, labels, grid_line_distance=32, source='train'):
    global use_GPU
    
    image_path = './dataset/'+source+'/'+image_id+'.jpg'
    if use_GPU:
        image = cv2.UMat(draw_bboxes(image_id, labels))
    else:
        image = draw_bboxes(image_id, labels)
    image = cv2.resize(image, (256, 256))
    
    # Vertical Lines
    prev_x = 0
    prev_y = 0
    for dist in range(0, 256, grid_line_distance):
        image = cv2.line(image, (prev_x, prev_y+(dist-prev_y)), (prev_x+256, prev_y+(dist-prev_y)), (0, 0, 255), 1, 1)
        prev_x = prev_x
        prev_y = dist
    
    # Horizontal Lines
    prev_x = 0
    prev_y = 0
    for dist in range(0, 256, grid_line_distance):
        image = cv2.line(image, (prev_x+(dist-prev_x), prev_y), (prev_x+(dist-prev_x), prev_y+256), (0, 0, 255), 1, 1)
        prev_x = dist
        prev_y = prev_y
        
    if use_GPU:
        image = cv2.UMat.get(image)
        
    else:
        image = image

    return image

# %% [markdown]
# ## Which grid size is optimal to select for Yolo-Similar model with an input image size of `256*256`?
# Answer: below the plot

# %%
fig, ax = plt.subplots(1, 2, figsize=(10*2, 10*2))
image_id = train_image_ids[3000]
ax[0].set_title('Grid size: 32*32')
ax[0].imshow(draw_grid_lines(image_id, train_labels[image_id], grid_line_distance=32 )) # 32*32 grid
ax[1].set_title('Grid size: 16*16')
ax[1].imshow(draw_grid_lines(image_id, train_labels[image_id], grid_line_distance=16 )) # 16*16 grid
fig.show()

# %% [markdown]
# 1. Here we can see that `32*32` grid is more effective than `16*16`
# 2. `16*16` grid is too closely packed and the mid-points of the anchors are not clear, Therefore, selecting `32*32` grid size is optimal.

# %%
train_image_ids[100]
# Out:
# '4d60c73db'

# %% [markdown]
# ### Cleaning Very small boxes

# %%
tiny_boxes = []

for i, image_id in enumerate(train_image_ids):
    for label in train_labels[image_id]:
        if label[2]*label[3] <= 10 and label[2]*label[3] != 0:
            tiny_boxes.append(i)
print(str(len(tiny_boxes)) + ' tiny boxes found')
# Out:
# 49 tiny boxes found

# %%
def clean_labels(train_image_ids, train_labels):
    good_labels = {}
    
    for i, image_id in enumerate(train_image_ids):
        good_labels[image_id] = []
        
        for j, label in enumerate(train_labels[image_id]):
            
            if label[2]*label[3] > 8000 and i not in [1079, 1371, 2020]:
                continue
                
            elif label[2]<5 or label[3]<5:
                continue
                
            else:
                good_labels[image_id].append(
                    train_labels[image_id][j]
                )
    return good_labels

# %%
train_labels = clean_labels(train_image_ids, train_labels)

# %% [markdown]
# # DataGenerator

# %%
class DataGenerator(tf.keras.utils.Sequence):

    def __init__(self, image_ids, image_pixels, labels=None, batch_size=1, shuffle=False, augment=False):
        self.image_ids = image_ids
        self.image_pixels = image_pixels
        self.labels = labels
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.augment = augment
        self.on_epoch_end()
        
        self.image_grid = self.form_image_grid()
        
        
    def form_image_grid(self):    
        image_grid = np.zeros((32, 32, 4))

        # x, y, width, height
        cell = [0, 0, 256 / 32, 256 / 32] 

        for i in range(0, 32):
            for j in range(0, 32):
                image_grid[i,j] = cell

                cell[0] = cell[0] + cell[2]

            cell[0] = 0
            cell[1] = cell[1] + cell[3]

        return image_grid

# %%
def __len__(self):
    return int(np.floor(len(self.image_ids) / self.batch_size))


def on_epoch_end(self):
    self.indexes = np.arange(len(self.image_ids))

    if self.shuffle == True:
        np.random.shuffle(self.indexes)


DataGenerator.__len__ = __len__
DataGenerator.on_epoch_end = on_epoch_end

# %%
DataGenerator.train_augmentations = albu.Compose([
        albu.RandomSizedCrop(
            min_max_height=(200, 200), 
            height=256, 
            width=256, 
            p=0.8
        ),
        albu.OneOf([
            albu.Flip(),
            albu.RandomRotate90(),
        ], p=1),
        albu.OneOf([
            albu.HueSaturationValue(),
            albu.RandomBrightnessContrast()
        ], p=1),
        albu.OneOf([
            albu.GaussNoise(),
            albu.GlassBlur(),
            albu.ISONoise(),
            albu.MultiplicativeNoise(),
        ], p=0.5),
        albu.Cutout(
            num_holes=8, 
            max_h_size=16, 
            max_w_size=16, 
            fill_value=0, 
            p=0.5
        ),
        albu.CLAHE(p=1),
        albu.ToGray(p=1),
    ], 
    bbox_params={'format': 'coco', 'label_fields': ['labels']})

DataGenerator.val_augmentations = albu.Compose([
    albu.CLAHE(p=1),
    albu.ToGray(p=1),
])

# %%
def __getitem__(self, index):
    indexes = self.indexes[index * self.batch_size:(index + 1) * self.batch_size]

    batch_ids = [self.image_ids[i] for i in indexes]

    X, y = self.__data_generation(batch_ids)

    return X, y


def __data_generation(self, batch_ids):
    X, y = [], []

    # Generate data
    for i, image_id in enumerate(batch_ids):
        pixels = self.image_pixels[image_id]
        bboxes = self.labels[image_id]

        if self.augment:     
            pixels, bboxes = self.augment_image(pixels, bboxes)
        else:
            pixels = self.contrast_image(pixels)
            bboxes = self.form_label_grid(bboxes)

        X.append(pixels)
        y.append(bboxes)

    return np.array(X), np.array(y)


def augment_image(self, pixels, bboxes):
    bbox_labels = np.ones(len(bboxes))

    aug_result = self.train_augmentations(image=pixels, bboxes=bboxes, labels=bbox_labels)

    bboxes = self.form_label_grid(aug_result['bboxes'])

    return np.array(aug_result['image']) / 255, bboxes


def contrast_image(self, pixels):        
    aug_result = self.val_augmentations(image=pixels)
    return np.array(aug_result['image']) / 255


DataGenerator.__getitem__ = __getitem__
DataGenerator.__data_generation = __data_generation
DataGenerator.augment_image = augment_image
DataGenerator.contrast_image = contrast_image

# %%
def form_label_grid(self, bboxes):
    label_grid = np.zeros((32, 32, 10))

    for i in range(0, 32):
        for j in range(0, 32):
            cell = self.image_grid[i,j]
            label_grid[i,j] = self.rect_intersect(cell, bboxes)

    return label_grid


def rect_intersect(self, cell, bboxes): 
    cell_x, cell_y, cell_width, cell_height = cell
    cell_x_max = cell_x + cell_width 
    cell_y_max = cell_y + cell_height
    
    anchor_one = np.array([0, 0, 0, 0, 0])
    anchor_two = np.array([0, 0, 0, 0, 0])

    # check all boxes
    for bbox in bboxes:
        box_x, box_y, box_width, box_height = bbox
        box_x_centre = box_x + (box_width / 2)
        box_y_centre = box_y + (box_height / 2)

        if(box_x_centre >= cell_x and box_x_centre < cell_x_max and box_y_centre >= cell_y and box_y_centre < cell_y_max):
            
            if anchor_one[0] == 0:
                anchor_one = self.yolo_shape(
                    [box_x, box_y, box_width, box_height], 
                    [cell_x, cell_y, cell_width, cell_height]
                )
            
            elif anchor_two[0] == 0:
                anchor_two = self.yolo_shape(
                    [box_x, box_y, box_width, box_height], 
                    [cell_x, cell_y, cell_width, cell_height]
                )
                
            else:
                break

    return np.concatenate((anchor_one, anchor_two), axis=None)


def yolo_shape(self, box, cell):
    box_x, box_y, box_width, box_height = box
    cell_x, cell_y, cell_width, cell_height = cell

    # top left x,y to centre x,y
    box_x = box_x + (box_width / 2)
    box_y = box_y + (box_height / 2)

    # offset bbox x,y to cell x,y
    box_x = (box_x - cell_x) / cell_width
    box_y = (box_y - cell_y) / cell_height

    # bbox width,height relative to cell width,height
    box_width = box_width / 256
    box_height = box_height / 256

    return [1, box_x, box_y, box_width, box_height]


DataGenerator.form_label_grid = form_label_grid
DataGenerator.rect_intersect = rect_intersect
DataGenerator.yolo_shape = yolo_shape

# %%
BATCH_SIZE = 2

train_generator = DataGenerator(
    train_image_ids,
    train_pixels,
    train_labels, 
    batch_size=BATCH_SIZE, 
    shuffle=True,
    augment=True
)

val_generator = DataGenerator(
    val_image_ids, 
    val_pixels,
    val_labels, 
    batch_size=10,
    shuffle=False,
    augment=False
)

image_grid = train_generator.image_grid

# %%
### Using Kaggle TPU for taining.

# %%
### For Using Kaggle TPU for taining.
# tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
# tf.config.experimental_connect_to_cluster(tpu)
# tf.tpu.experimental.initialize_tpu_system(tpu)

# tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)

# %%
def add_main_block(num_times_to_add_block: int, x, x_shortcut, filters: int, kernel_size: tuple, strides: tuple, block_number=None, padding: str ='same', alpha: str = 0.1):
    
    for _ in range(num_times_to_add_block):
        x = Conv2D(filters, kernel_size, strides=strides, padding=padding)(x)
        x = BatchNormalization()(x)
        x = LeakyReLU(alpha=alpha)(x)
    
        x = Conv2D(filters*2, kernel_size, strides=strides, padding=padding)(x)
        x = BatchNormalization()(x)
        x = LeakyReLU(alpha=alpha)(x)
    
        x = Add()([x_shortcut, x])
        x = LeakyReLU(alpha=alpha)(x)
        
        x_shortcut = x
        
    return x, x_shortcut



def add_res_block(x, x_shortcut=None, filters: int = None, kernel_size: tuple = None, strides: tuple = None, block_number=None, padding: str = 'same', alpha: float = 0.1):
    x = tf.keras.layers.Conv2D(filters, kernel_size, strides=strides, padding=padding)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.LeakyReLU(alpha=alpha)(x)

    x_shortcut = x
    
    return x, x_shortcut

# %%
# def custom_loss(y_true, y_pred):
    
#     global BATCH_SIZE
    
#     #------------- For GPU Computing ----------------#
#     binary_crossentropy = prob_loss = tf.keras.losses.BinaryCrossentropy(
#         reduction=tf.keras.losses.Reduction.SUM_OVER_BATCH_SIZE
#     )

#     prob_loss = binary_crossentropy(
#         tf.concat([y_true[:,:,:,0], y_true[:,:,:,5]], axis=0), 
#         tf.concat([y_pred[:,:,:,0], y_pred[:,:,:,5]], axis=0)
#      )
#     #-------------- End of GPU Computing ---------------#
    
    
    
#     #------------ For TPU Computing ------------#
# #     binary_crossentropy = prob_loss = tf.keras.losses.BinaryCrossentropy(
# #         reduction=tf.keras.losses.Reduction.NONE)
    
# #     # Binary Cross Entropy loss for TPU Computing.
# #     reduce_sum = tf.reduce_sum(binary_crossentropy(
# #         tf.concat([y_true[:,:,:,0], y_true[:,:,:,5]], axis=0),
# #         tf.concat([y_pred[:,:,:,0], y_pred[:,:,:,5]], axis=0)
# #     ))
    
# #     prob_loss = reduce_sum * (1. / BATCH_SIZE)
#     #-------------- End of TPU Computing --------------#
    
#     xy_loss = tf.keras.losses.MSE(
#         tf.concat([y_true[:,:,:,1:3], y_true[:,:,:,6:8]], axis=0), 
#         tf.concat([y_pred[:,:,:,1:3], y_pred[:,:,:,6:8]], axis=0)
#     )
    
#     wh_loss = tf.keras.losses.MSE(
#         tf.concat([y_true[:,:,:,3:5], y_true[:,:,:,8:10]], axis=0), 
#         tf.concat([y_pred[:,:,:,3:5], y_pred[:,:,:,8:10]], axis=0)
#     )
    
#     bboxes_mask = get_mask(y_true)
    
#     xy_loss = xy_loss * bboxes_mask
#     wh_loss = wh_loss * bboxes_mask
    
#     return prob_loss + xy_loss + wh_loss


# def get_mask(y_true):
#     anchor_one_mask = tf.where(
#         y_true[:,:,:,0] == 0, 
#         0.5, 
#         5.0
#     )
    
#     anchor_two_mask = tf.where(
#         y_true[:,:,:,5] == 0, 
#         0.5, 
#         5.0
#     )
    
#     bboxes_mask = tf.concat(
#         [anchor_one_mask,anchor_two_mask],
#         axis=0
#     )
    
#     return bboxes_mask

# %%
#with tpu_strategy.scope():


x_input = Input(shape=(256, 256, 3))

x = Conv2D(32, (3, 3), strides=(1, 1), padding='same')(x_input)
x = BatchNormalization()(x)
x = LeakyReLU(alpha=0.1)(x)


#------------ Block 1 -------------#
#-- Res-block-1 --#
x, x_shortcut = add_res_block(x, filters=64, kernel_size=(3, 3), strides=(1, 1), padding='same', alpha=0.1)
#-- Main-Block-1 --#
x, x_shortcut = add_main_block(2, x, x_shortcut, 32, kernel_size=(3, 3), strides=(1, 1), padding='same', alpha=0.1)


#------------ Block 2 -------------#
#-- Res-block-2 --#
x, x_shortcut = add_res_block(x, x_shortcut=x_shortcut, filters=128, kernel_size=(3, 3), strides=(1, 1), padding='same', alpha=0.1)
#-- Main-Block 2 --#
x, x_shortcut = add_main_block(2, x, x_shortcut, 64, kernel_size=(3, 3), strides=(1, 1), padding='same', alpha=0.1)


#------------ Block 3 -------------#
#-- Res-block 3 --#
x, x_shortcut = add_res_block(x, x_shortcut, filters=256, kernel_size=(3, 3), strides=(2, 2), padding='same', alpha=0.1)
#-- Main-Block --#
x, x_shortcut = add_main_block(2, x, x_shortcut, 128, kernel_size=(3, 3), strides=(1, 1), padding='same', alpha=0.1)


#------------ Block 4 -------------#
#-- Res-Block 4 --#
x, x_shortcut = add_res_block(x, x_shortcut, filters=512, kernel_size=(3, 3), strides=(2, 2), padding='same', alpha=0.1)
#-- Main-Block 4 --#
x, x_shortcut = add_main_block(2, x, x_shortcut, 256, kernel_size=(3, 3), strides=(1, 1), padding='same', alpha=0.1)


#------------ Block 5 -------------#
#-- Res-Block 5 --#
x, x_shortcut = add_res_block(x, x_shortcut, filters=1024, kernel_size=(3, 3), strides=(2, 2), padding='same', alpha=0.1)
#-- Main-Block 5 --#
x, x_shortcut = add_main_block(2, x, x_shortcut, 512, kernel_size=(3, 3), strides=(1, 1), padding='same', alpha=0.1)


#------------ Output Layers -------------#
x = Conv2D(512, (3, 3), strides=(1, 1), padding='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU(alpha=0.1)(x)

x = Conv2D(256, (3, 3), strides=(1, 1), padding='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU(alpha=0.1)(x)

x = Conv2D(128, (3, 3), strides=(1, 1), padding='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU(alpha=0.1)(x)

predictions= x = Conv2D(10, (1, 1), strides=(1, 1), activation='sigmoid', dtype="float32")(x)


model = tf.keras.Model(inputs=x_input, outputs=predictions)

# %%
# optimiser = tf.keras.optimizers.Adam(learning_rate=0.0001)
# model.compile(
#     optimizer=optimiser, 
#     loss=custom_loss
# )

# %% [markdown]
# model = Model(inputs=x_input, outputs=predictions)

# %% [markdown]
# x_input = tf.keras.Input(shape=(256,256,3))
#
# x = tf.keras.layers.Conv2D(32, (3, 3), strides=(1, 1), padding='same')(x_input)
# x = tf.keras.layers.BatchNormalization()(x)
# x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
#
# ########## block 1 ##########
# x = tf.keras.layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same')(x)
# x = tf.keras.layers.BatchNormalization()(x)
# x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
#
# x_shortcut = x
#
# # for i in range(2):
# #     x = tf.keras.layers.Conv2D(32, (3, 3), strides=(1, 1), padding='same')(x)
# #     x = tf.keras.layers.BatchNormalization()(x)
# #     x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
#
# #     x = tf.keras.layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same')(x)
# #     x = tf.keras.layers.BatchNormalization()(x)
# #     x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
#
# #     x = tf.keras.layers.Add()([x_shortcut, x])
# #     x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
#
# #     x_shortcut = x
#
# x, x_shortcut = add_main_block(2, x, x_shortcut, 32, kernel_size=(3, 3), strides=(1, 1), padding='same', alpha=0.1)
#
#
# ########## block 2 ##########
# x = tf.keras.layers.Conv2D(128, (3, 3), strides=(1, 1), padding='same')(x)
# x = tf.keras.layers.BatchNormalization()(x)
# x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
#
# x_shortcut = x
#
# # for i in range(2):
# #     x = tf.keras.layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same')(x)
# #     x = tf.keras.layers.BatchNormalization()(x)
# #     x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
#
# #     x = tf.keras.layers.Conv2D(128, (3, 3), strides=(1, 1), padding='same')(x)
# #     x = tf.keras.layers.BatchNormalization()(x)
# #     x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
#
# #     x = tf.keras.layers.Add()([x_shortcut, x])
# #     x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
#
# #     x_shortcut = x
#
# x, x_shortcut = add_main_block(2, x, x_shortcut, 64, kernel_size=(3, 3), strides=(1, 1), padding='same', alpha=0.1)
#
# ########## block 3 ##########
# x = tf.keras.layers.Conv2D(256, (3, 3), strides=(2, 2), padding='same')(x)
# x = tf.keras.layers.BatchNormalization()(x)
# x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
#
# x_shortcut = x
#
# # for i in range(8):
# #     x = tf.keras.layers.Conv2D(128, (3, 3), strides=(1, 1), padding='same')(x)
# #     x = tf.keras.layers.BatchNormalization()(x)
# #     x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
#
# #     x = tf.keras.layers.Conv2D(256, (3, 3), strides=(1, 1), padding='same')(x)
# #     x = tf.keras.layers.BatchNormalization()(x)
# #     x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
#
# #     x = tf.keras.layers.Add()([x_shortcut, x])
# #     x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
#
# #     x_shortcut = x
#
# x, x_shortcut = add_main_block(8, x, x_shortcut, 128, kernel_size=(3, 3), strides=(1, 1), padding='same', alpha=0.1)
#
#
# ########## block 4 ##########
# x = tf.keras.layers.Conv2D(512, (3, 3), strides=(2, 2), padding='same')(x)
# x = tf.keras.layers.BatchNormalization()(x)
# x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
#
# x_shortcut = x
#
# # for i in range(8):
# #     x = tf.keras.layers.Conv2D(256, (3, 3), strides=(1, 1), padding='same')(x)
# #     x = tf.keras.layers.BatchNormalization()(x)
# #     x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
#
# #     x = tf.keras.layers.Conv2D(512, (3, 3), strides=(1, 1), padding='same')(x)
# #     x = tf.keras.layers.BatchNormalization()(x)
# #     x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
#
# #     x = tf.keras.layers.Add()([x_shortcut, x])
# #     x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
#
# #     x_shortcut = x
#
# x, x_shortcut = add_main_block(8, x, x_shortcut, 256, kernel_size=(3, 3), strides=(1, 1), padding='same', alpha=0.1)
#
# ########## block 5 ##########
# x = tf.keras.layers.Conv2D(1024, (3, 3), strides=(2, 2), padding='same')(x)
# x = tf.keras.layers.BatchNormalization()(x)
# x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
#
# x_shortcut = x
#
# # for i in range(4):
# #     x = tf.keras.layers.Conv2D(512, (3, 3), strides=(1, 1), padding='same')(x)
# #     x = tf.keras.layers.BatchNormalization()(x)
# #     x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
#
# #     x = tf.keras.layers.Conv2D(1024, (3, 3), strides=(1, 1), padding='same')(x)
# #     x = tf.keras.layers.BatchNormalization()(x)
# #     x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
#
# #     x = tf.keras.layers.Add()([x_shortcut, x])
# #     x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
#
# #     x_shortcut = x
#
# x, x_shortcut = add_main_block(8, x, x_shortcut, 512, kernel_size=(3, 3), strides=(1, 1), padding='same', alpha=0.1)
#
# ########## output layers ##########
# x = tf.keras.layers.Conv2D(512, (3, 3), strides=(1, 1), padding='same')(x)
# x = tf.keras.layers.BatchNormalization()(x)
# x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
#
# x = tf.keras.layers.Conv2D(256, (3, 3), strides=(1, 1), padding='same')(x)
# x = tf.keras.layers.BatchNormalization()(x)
# x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
#
# x = tf.keras.layers.Conv2D(128, (3, 3), strides=(1, 1), padding='same')(x)
# x = tf.keras.layers.BatchNormalization()(x)
# x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
#
# predictions = tf.keras.layers.Conv2D(10, (1, 1), strides=(1, 1), activation='sigmoid', dtype='float32')(x)
#
# model = tf.keras.Model(inputs=x_input, outputs=predictions)

# %%
def custom_loss(y_true, y_pred):
    binary_crossentropy = prob_loss = tf.keras.losses.BinaryCrossentropy(
        reduction=tf.keras.losses.Reduction.SUM_OVER_BATCH_SIZE
    )
    
    prob_loss = binary_crossentropy(
        tf.concat([y_true[:,:,:,0], y_true[:,:,:,5]], axis=0), 
        tf.concat([y_pred[:,:,:,0], y_pred[:,:,:,5]], axis=0)
    )
    
    xy_loss = tf.keras.losses.MSE(
        tf.concat([y_true[:,:,:,1:3], y_true[:,:,:,6:8]], axis=0), 
        tf.concat([y_pred[:,:,:,1:3], y_pred[:,:,:,6:8]], axis=0)
    )
    
    wh_loss = tf.keras.losses.MSE(
        tf.concat([y_true[:,:,:,3:5], y_true[:,:,:,8:10]], axis=0), 
        tf.concat([y_pred[:,:,:,3:5], y_pred[:,:,:,8:10]], axis=0)
    )
    
    bboxes_mask = get_mask(y_true)
    
    xy_loss = xy_loss * bboxes_mask
    wh_loss = wh_loss * bboxes_mask
    
    return prob_loss + xy_loss + wh_loss


def get_mask(y_true):
    anchor_one_mask = tf.where(
        y_true[:,:,:,0] == 0, 
        0.5, 
        5.0
    )
    
    anchor_two_mask = tf.where(
        y_true[:,:,:,5] == 0, 
        0.5, 
        5.0
    )
    
    bboxes_mask = tf.concat(
        [anchor_one_mask,anchor_two_mask],
        axis=0
    )
    
    return bboxes_mask

# %%
optimiser = tf.keras.optimizers.Adam(learning_rate=0.0001)

model.compile(
    optimizer=optimiser, 
    loss=custom_loss
)

# %%
callbacks = [
    tf.keras.callbacks.ReduceLROnPlateau(monitor='loss', patience=2, verbose=1),
    tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5, verbose=1, restore_best_weights=True),
    keras.callbacks.ModelCheckpoint(filepath="Model_save_diff_user.h5", save_best_only=True, monitor='loss', save_weights_only=True, verbose=1)
]

# %%
model.summary()
# Out:
# Model: "functional_11"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, 256, 256, 32) 896         input_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_185 (BatchN (None, 256, 256, 32) 128         conv2d_190[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_255 (LeakyReLU)     (None, 256, 256, 32) 0           batch_normalization_185[0][0]
# __________________________________________________________________________________________________
# conv2d_191 (Conv2D)             (None, 256, 256, 64) 18496       leaky_re_lu_255[0][0]
# __________________________________________________________________________________________________
# batch_normalization_186 (BatchN (None, 256, 256, 64) 256         conv2d_191[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_256 (LeakyReLU)     (None, 256, 256, 64) 0           batch_normalization_186[0][0]
# __________________________________________________________________________________________________
# conv2d_192 (Conv2D)             (None, 256, 256, 32) 18464       leaky_re_lu_256[0][0]
# __________________________________________________________________________________________________
# batch_normalization_187 (BatchN (None, 256, 256, 32) 128         conv2d_192[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_257 (LeakyReLU)     (None, 256, 256, 32) 0           batch_normalization_187[0][0]
# __________________________________________________________________________________________________
# conv2d_193 (Conv2D)             (None, 256, 256, 64) 18496       leaky_re_lu_257[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188 (BatchN (None, 256, 256, 64) 256         conv2d_193[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_258 (LeakyReLU)     (None, 256, 256, 64) 0           batch_normalization_188[0][0]
# __________________________________________________________________________________________________
# add_70 (Add)                    (None, 256, 256, 64) 0           leaky_re_lu_256[0][0]
#                                                                  leaky_re_lu_258[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_259 (LeakyReLU)     (None, 256, 256, 64) 0           add_70[0][0]
# __________________________________________________________________________________________________
# conv2d_194 (Conv2D)             (None, 256, 256, 32) 18464       leaky_re_lu_259[0][0]
# __________________________________________________________________________________________________
# batch_normalization_189 (BatchN (None, 256, 256, 32) 128         conv2d_194[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_260 (LeakyReLU)     (None, 256, 256, 32) 0           batch_normalization_189[0][0]
# __________________________________________________________________________________________________
# conv2d_195 (Conv2D)             (None, 256, 256, 64) 18496       leaky_re_lu_260[0][0]
# __________________________________________________________________________________________________
# batch_normalization_190 (BatchN (None, 256, 256, 64) 256         conv2d_195[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_261 (LeakyReLU)     (None, 256, 256, 64) 0           batch_normalization_190[0][0]
# __________________________________________________________________________________________________
# add_71 (Add)                    (None, 256, 256, 64) 0           leaky_re_lu_259[0][0]
#                                                                  leaky_re_lu_261[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_262 (LeakyReLU)     (None, 256, 256, 64) 0           add_71[0][0]
# __________________________________________________________________________________________________
# conv2d_196 (Conv2D)             (None, 256, 256, 128 73856       leaky_re_lu_262[0][0]
# __________________________________________________________________________________________________
# batch_normalization_191 (BatchN (None, 256, 256, 128 512         conv2d_196[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_263 (LeakyReLU)     (None, 256, 256, 128 0           batch_normalization_191[0][0]
# __________________________________________________________________________________________________
# conv2d_197 (Conv2D)             (None, 256, 256, 64) 73792       leaky_re_lu_263[0][0]
# __________________________________________________________________________________________________
# batch_normalization_192 (BatchN (None, 256, 256, 64) 256         conv2d_197[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_264 (LeakyReLU)     (None, 256, 256, 64) 0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# conv2d_198 (Conv2D)             (None, 256, 256, 128 73856       leaky_re_lu_264[0][0]
# __________________________________________________________________________________________________
# batch_normalization_193 (BatchN (None, 256, 256, 128 512         conv2d_198[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_265 (LeakyReLU)     (None, 256, 256, 128 0           batch_normalization_193[0][0]
# __________________________________________________________________________________________________
# add_72 (Add)                    (None, 256, 256, 128 0           leaky_re_lu_263[0][0]
#                                                                  leaky_re_lu_265[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_266 (LeakyReLU)     (None, 256, 256, 128 0           add_72[0][0]
# __________________________________________________________________________________________________
# conv2d_199 (Conv2D)             (None, 256, 256, 64) 73792       leaky_re_lu_266[0][0]
# __________________________________________________________________________________________________
# batch_normalization_194 (BatchN (None, 256, 256, 64) 256         conv2d_199[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_267 (LeakyReLU)     (None, 256, 256, 64) 0           batch_normalization_194[0][0]
# __________________________________________________________________________________________________
# conv2d_200 (Conv2D)             (None, 256, 256, 128 73856       leaky_re_lu_267[0][0]
# __________________________________________________________________________________________________
# batch_normalization_195 (BatchN (None, 256, 256, 128 512         conv2d_200[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_268 (LeakyReLU)     (None, 256, 256, 128 0           batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# add_73 (Add)                    (None, 256, 256, 128 0           leaky_re_lu_266[0][0]
#                                                                  leaky_re_lu_268[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_269 (LeakyReLU)     (None, 256, 256, 128 0           add_73[0][0]
# __________________________________________________________________________________________________
# conv2d_201 (Conv2D)             (None, 128, 128, 256 295168      leaky_re_lu_269[0][0]
# __________________________________________________________________________________________________
# batch_normalization_196 (BatchN (None, 128, 128, 256 1024        conv2d_201[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_270 (LeakyReLU)     (None, 128, 128, 256 0           batch_normalization_196[0][0]
# __________________________________________________________________________________________________
# conv2d_202 (Conv2D)             (None, 128, 128, 128 295040      leaky_re_lu_270[0][0]
# __________________________________________________________________________________________________
# batch_normalization_197 (BatchN (None, 128, 128, 128 512         conv2d_202[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_271 (LeakyReLU)     (None, 128, 128, 128 0           batch_normalization_197[0][0]
# __________________________________________________________________________________________________
# conv2d_203 (Conv2D)             (None, 128, 128, 256 295168      leaky_re_lu_271[0][0]
# __________________________________________________________________________________________________
# batch_normalization_198 (BatchN (None, 128, 128, 256 1024        conv2d_203[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_272 (LeakyReLU)     (None, 128, 128, 256 0           batch_normalization_198[0][0]
# __________________________________________________________________________________________________
# add_74 (Add)                    (None, 128, 128, 256 0           leaky_re_lu_270[0][0]
#                                                                  leaky_re_lu_272[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_273 (LeakyReLU)     (None, 128, 128, 256 0           add_74[0][0]
# __________________________________________________________________________________________________
# conv2d_204 (Conv2D)             (None, 128, 128, 128 295040      leaky_re_lu_273[0][0]
# __________________________________________________________________________________________________
# batch_normalization_199 (BatchN (None, 128, 128, 128 512         conv2d_204[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_274 (LeakyReLU)     (None, 128, 128, 128 0           batch_normalization_199[0][0]
# __________________________________________________________________________________________________
# conv2d_205 (Conv2D)             (None, 128, 128, 256 295168      leaky_re_lu_274[0][0]
# __________________________________________________________________________________________________
# batch_normalization_200 (BatchN (None, 128, 128, 256 1024        conv2d_205[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_275 (LeakyReLU)     (None, 128, 128, 256 0           batch_normalization_200[0][0]
# __________________________________________________________________________________________________
# add_75 (Add)                    (None, 128, 128, 256 0           leaky_re_lu_273[0][0]
#                                                                  leaky_re_lu_275[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_276 (LeakyReLU)     (None, 128, 128, 256 0           add_75[0][0]
# __________________________________________________________________________________________________
# conv2d_206 (Conv2D)             (None, 64, 64, 512)  1180160     leaky_re_lu_276[0][0]
# __________________________________________________________________________________________________
# batch_normalization_201 (BatchN (None, 64, 64, 512)  2048        conv2d_206[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_277 (LeakyReLU)     (None, 64, 64, 512)  0           batch_normalization_201[0][0]
# __________________________________________________________________________________________________
# conv2d_207 (Conv2D)             (None, 64, 64, 256)  1179904     leaky_re_lu_277[0][0]
# __________________________________________________________________________________________________
# batch_normalization_202 (BatchN (None, 64, 64, 256)  1024        conv2d_207[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_278 (LeakyReLU)     (None, 64, 64, 256)  0           batch_normalization_202[0][0]
# __________________________________________________________________________________________________
# conv2d_208 (Conv2D)             (None, 64, 64, 512)  1180160     leaky_re_lu_278[0][0]
# __________________________________________________________________________________________________
# batch_normalization_203 (BatchN (None, 64, 64, 512)  2048        conv2d_208[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_279 (LeakyReLU)     (None, 64, 64, 512)  0           batch_normalization_203[0][0]
# __________________________________________________________________________________________________
# add_76 (Add)                    (None, 64, 64, 512)  0           leaky_re_lu_277[0][0]
#                                                                  leaky_re_lu_279[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_280 (LeakyReLU)     (None, 64, 64, 512)  0           add_76[0][0]
# __________________________________________________________________________________________________
# conv2d_209 (Conv2D)             (None, 64, 64, 256)  1179904     leaky_re_lu_280[0][0]
# __________________________________________________________________________________________________
# batch_normalization_204 (BatchN (None, 64, 64, 256)  1024        conv2d_209[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_281 (LeakyReLU)     (None, 64, 64, 256)  0           batch_normalization_204[0][0]
# __________________________________________________________________________________________________
# conv2d_210 (Conv2D)             (None, 64, 64, 512)  1180160     leaky_re_lu_281[0][0]
# __________________________________________________________________________________________________
# batch_normalization_205 (BatchN (None, 64, 64, 512)  2048        conv2d_210[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_282 (LeakyReLU)     (None, 64, 64, 512)  0           batch_normalization_205[0][0]
# __________________________________________________________________________________________________
# add_77 (Add)                    (None, 64, 64, 512)  0           leaky_re_lu_280[0][0]
#                                                                  leaky_re_lu_282[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_283 (LeakyReLU)     (None, 64, 64, 512)  0           add_77[0][0]
# __________________________________________________________________________________________________
# conv2d_211 (Conv2D)             (None, 32, 32, 1024) 4719616     leaky_re_lu_283[0][0]
# __________________________________________________________________________________________________
# batch_normalization_206 (BatchN (None, 32, 32, 1024) 4096        conv2d_211[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_284 (LeakyReLU)     (None, 32, 32, 1024) 0           batch_normalization_206[0][0]
# __________________________________________________________________________________________________
# conv2d_212 (Conv2D)             (None, 32, 32, 512)  4719104     leaky_re_lu_284[0][0]
# __________________________________________________________________________________________________
# batch_normalization_207 (BatchN (None, 32, 32, 512)  2048        conv2d_212[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_285 (LeakyReLU)     (None, 32, 32, 512)  0           batch_normalization_207[0][0]
# __________________________________________________________________________________________________
# conv2d_213 (Conv2D)             (None, 32, 32, 1024) 4719616     leaky_re_lu_285[0][0]
# __________________________________________________________________________________________________
# batch_normalization_208 (BatchN (None, 32, 32, 1024) 4096        conv2d_213[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_286 (LeakyReLU)     (None, 32, 32, 1024) 0           batch_normalization_208[0][0]
# __________________________________________________________________________________________________
# add_78 (Add)                    (None, 32, 32, 1024) 0           leaky_re_lu_284[0][0]
#                                                                  leaky_re_lu_286[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_287 (LeakyReLU)     (None, 32, 32, 1024) 0           add_78[0][0]
# __________________________________________________________________________________________________
# conv2d_214 (Conv2D)             (None, 32, 32, 512)  4719104     leaky_re_lu_287[0][0]
# __________________________________________________________________________________________________
# batch_normalization_209 (BatchN (None, 32, 32, 512)  2048        conv2d_214[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_288 (LeakyReLU)     (None, 32, 32, 512)  0           batch_normalization_209[0][0]
# __________________________________________________________________________________________________
# conv2d_215 (Conv2D)             (None, 32, 32, 1024) 4719616     leaky_re_lu_288[0][0]
# __________________________________________________________________________________________________
# batch_normalization_210 (BatchN (None, 32, 32, 1024) 4096        conv2d_215[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_289 (LeakyReLU)     (None, 32, 32, 1024) 0           batch_normalization_210[0][0]
# __________________________________________________________________________________________________
# add_79 (Add)                    (None, 32, 32, 1024) 0           leaky_re_lu_287[0][0]
#                                                                  leaky_re_lu_289[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_290 (LeakyReLU)     (None, 32, 32, 1024) 0           add_79[0][0]
# __________________________________________________________________________________________________
# conv2d_216 (Conv2D)             (None, 32, 32, 512)  4719104     leaky_re_lu_290[0][0]
# __________________________________________________________________________________________________
# batch_normalization_211 (BatchN (None, 32, 32, 512)  2048        conv2d_216[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_291 (LeakyReLU)     (None, 32, 32, 512)  0           batch_normalization_211[0][0]
# __________________________________________________________________________________________________
# conv2d_217 (Conv2D)             (None, 32, 32, 256)  1179904     leaky_re_lu_291[0][0]
# __________________________________________________________________________________________________
# batch_normalization_212 (BatchN (None, 32, 32, 256)  1024        conv2d_217[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_292 (LeakyReLU)     (None, 32, 32, 256)  0           batch_normalization_212[0][0]
# __________________________________________________________________________________________________
# conv2d_218 (Conv2D)             (None, 32, 32, 128)  295040      leaky_re_lu_292[0][0]
# __________________________________________________________________________________________________
# batch_normalization_213 (BatchN (None, 32, 32, 128)  512         conv2d_218[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_293 (LeakyReLU)     (None, 32, 32, 128)  0           batch_normalization_213[0][0]
# __________________________________________________________________________________________________
# conv2d_219 (Conv2D)             (None, 32, 32, 10)   1290        leaky_re_lu_293[0][0]
# ==================================================================================================
# Total params: 37,666,186
# Trainable params: 37,648,458
# Non-trainable params: 17,728
# __________________________________________________________________________________________________

# %%
model.load_weights("./Model_save_diff_user.h5")

# %%
model_json = model.to_json()
with open("Model_save_structure_diff_user.h5", "w") as json_file:
    json_file.write(model_json)
model.save_weights("Model_save_diff_user.h5")

# %%
history = model.fit_generator(
    train_generator,
    validation_data=val_generator,
    epochs=80,
    callbacks=callbacks
)

# %%
x_input = tf.keras.Input(shape=(256,256,3))

x = tf.keras.layers.Conv2D(32, (3, 3), strides=(1, 1), padding='same')(x_input)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

########## block 1 ##########
x = tf.keras.layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

x_shortcut = x

for i in range(2):
    x = tf.keras.layers.Conv2D(32, (3, 3), strides=(1, 1), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x = tf.keras.layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x = tf.keras.layers.Add()([x_shortcut, x])
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x_shortcut = x


########## block 2 ##########
x = tf.keras.layers.Conv2D(128, (3, 3), strides=(1, 1), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

x_shortcut = x

for i in range(2):
    x = tf.keras.layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x = tf.keras.layers.Conv2D(128, (3, 3), strides=(1, 1), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x = tf.keras.layers.Add()([x_shortcut, x])
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x_shortcut = x

########## block 3 ##########
x = tf.keras.layers.Conv2D(256, (3, 3), strides=(2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

x_shortcut = x

for i in range(8):
    x = tf.keras.layers.Conv2D(128, (3, 3), strides=(1, 1), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x = tf.keras.layers.Conv2D(256, (3, 3), strides=(1, 1), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x = tf.keras.layers.Add()([x_shortcut, x])
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x_shortcut = x

    
########## block 4 ##########
x = tf.keras.layers.Conv2D(512, (3, 3), strides=(2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

x_shortcut = x

for i in range(8):
    x = tf.keras.layers.Conv2D(256, (3, 3), strides=(1, 1), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x = tf.keras.layers.Conv2D(512, (3, 3), strides=(1, 1), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x = tf.keras.layers.Add()([x_shortcut, x])
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x_shortcut = x

########## block 5 ##########
x = tf.keras.layers.Conv2D(1024, (3, 3), strides=(2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

x_shortcut = x

for i in range(4):
    x = tf.keras.layers.Conv2D(512, (3, 3), strides=(1, 1), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x = tf.keras.layers.Conv2D(1024, (3, 3), strides=(1, 1), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x = tf.keras.layers.Add()([x_shortcut, x])
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x_shortcut = x

########## output layers ##########
x = tf.keras.layers.Conv2D(512, (3, 3), strides=(1, 1), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

x = tf.keras.layers.Conv2D(256, (3, 3), strides=(1, 1), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

x = tf.keras.layers.Conv2D(128, (3, 3), strides=(1, 1), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

predictions = tf.keras.layers.Conv2D(10, (1, 1), strides=(1, 1), activation='sigmoid')(x)

model = tf.keras.Model(inputs=x_input, outputs=predictions)

# %%
model.summary()
# Out:
# Model: "functional_13"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_220 (Conv2D)             (None, 256, 256, 32) 896         input_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_214 (BatchN (None, 256, 256, 32) 128         conv2d_220[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_294 (LeakyReLU)     (None, 256, 256, 32) 0           batch_normalization_214[0][0]
# __________________________________________________________________________________________________
# conv2d_221 (Conv2D)             (None, 256, 256, 64) 18496       leaky_re_lu_294[0][0]
# __________________________________________________________________________________________________
# batch_normalization_215 (BatchN (None, 256, 256, 64) 256         conv2d_221[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_295 (LeakyReLU)     (None, 256, 256, 64) 0           batch_normalization_215[0][0]
# __________________________________________________________________________________________________
# conv2d_222 (Conv2D)             (None, 256, 256, 32) 18464       leaky_re_lu_295[0][0]
# __________________________________________________________________________________________________
# batch_normalization_216 (BatchN (None, 256, 256, 32) 128         conv2d_222[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_296 (LeakyReLU)     (None, 256, 256, 32) 0           batch_normalization_216[0][0]
# __________________________________________________________________________________________________
# conv2d_223 (Conv2D)             (None, 256, 256, 64) 18496       leaky_re_lu_296[0][0]
# __________________________________________________________________________________________________
# batch_normalization_217 (BatchN (None, 256, 256, 64) 256         conv2d_223[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_297 (LeakyReLU)     (None, 256, 256, 64) 0           batch_normalization_217[0][0]
# __________________________________________________________________________________________________
# add_80 (Add)                    (None, 256, 256, 64) 0           leaky_re_lu_295[0][0]
#                                                                  leaky_re_lu_297[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_298 (LeakyReLU)     (None, 256, 256, 64) 0           add_80[0][0]
# __________________________________________________________________________________________________
# conv2d_224 (Conv2D)             (None, 256, 256, 32) 18464       leaky_re_lu_298[0][0]
# __________________________________________________________________________________________________
# batch_normalization_218 (BatchN (None, 256, 256, 32) 128         conv2d_224[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_299 (LeakyReLU)     (None, 256, 256, 32) 0           batch_normalization_218[0][0]
# __________________________________________________________________________________________________
# conv2d_225 (Conv2D)             (None, 256, 256, 64) 18496       leaky_re_lu_299[0][0]
# __________________________________________________________________________________________________
# batch_normalization_219 (BatchN (None, 256, 256, 64) 256         conv2d_225[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_300 (LeakyReLU)     (None, 256, 256, 64) 0           batch_normalization_219[0][0]
# __________________________________________________________________________________________________
# add_81 (Add)                    (None, 256, 256, 64) 0           leaky_re_lu_298[0][0]
#                                                                  leaky_re_lu_300[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_301 (LeakyReLU)     (None, 256, 256, 64) 0           add_81[0][0]
# __________________________________________________________________________________________________
# conv2d_226 (Conv2D)             (None, 256, 256, 128 73856       leaky_re_lu_301[0][0]
# __________________________________________________________________________________________________
# batch_normalization_220 (BatchN (None, 256, 256, 128 512         conv2d_226[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_302 (LeakyReLU)     (None, 256, 256, 128 0           batch_normalization_220[0][0]
# __________________________________________________________________________________________________
# conv2d_227 (Conv2D)             (None, 256, 256, 64) 73792       leaky_re_lu_302[0][0]
# __________________________________________________________________________________________________
# batch_normalization_221 (BatchN (None, 256, 256, 64) 256         conv2d_227[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_303 (LeakyReLU)     (None, 256, 256, 64) 0           batch_normalization_221[0][0]
# __________________________________________________________________________________________________
# conv2d_228 (Conv2D)             (None, 256, 256, 128 73856       leaky_re_lu_303[0][0]
# __________________________________________________________________________________________________
# batch_normalization_222 (BatchN (None, 256, 256, 128 512         conv2d_228[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_304 (LeakyReLU)     (None, 256, 256, 128 0           batch_normalization_222[0][0]
# __________________________________________________________________________________________________
# add_82 (Add)                    (None, 256, 256, 128 0           leaky_re_lu_302[0][0]
#                                                                  leaky_re_lu_304[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_305 (LeakyReLU)     (None, 256, 256, 128 0           add_82[0][0]
# __________________________________________________________________________________________________
# conv2d_229 (Conv2D)             (None, 256, 256, 64) 73792       leaky_re_lu_305[0][0]
# __________________________________________________________________________________________________
# batch_normalization_223 (BatchN (None, 256, 256, 64) 256         conv2d_229[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_306 (LeakyReLU)     (None, 256, 256, 64) 0           batch_normalization_223[0][0]
# __________________________________________________________________________________________________
# conv2d_230 (Conv2D)             (None, 256, 256, 128 73856       leaky_re_lu_306[0][0]
# __________________________________________________________________________________________________
# batch_normalization_224 (BatchN (None, 256, 256, 128 512         conv2d_230[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_307 (LeakyReLU)     (None, 256, 256, 128 0           batch_normalization_224[0][0]
# __________________________________________________________________________________________________
# add_83 (Add)                    (None, 256, 256, 128 0           leaky_re_lu_305[0][0]
#                                                                  leaky_re_lu_307[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_308 (LeakyReLU)     (None, 256, 256, 128 0           add_83[0][0]
# __________________________________________________________________________________________________
# conv2d_231 (Conv2D)             (None, 128, 128, 256 295168      leaky_re_lu_308[0][0]
# __________________________________________________________________________________________________
# batch_normalization_225 (BatchN (None, 128, 128, 256 1024        conv2d_231[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_309 (LeakyReLU)     (None, 128, 128, 256 0           batch_normalization_225[0][0]
# __________________________________________________________________________________________________
# conv2d_232 (Conv2D)             (None, 128, 128, 128 295040      leaky_re_lu_309[0][0]
# __________________________________________________________________________________________________
# batch_normalization_226 (BatchN (None, 128, 128, 128 512         conv2d_232[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_310 (LeakyReLU)     (None, 128, 128, 128 0           batch_normalization_226[0][0]
# __________________________________________________________________________________________________
# conv2d_233 (Conv2D)             (None, 128, 128, 256 295168      leaky_re_lu_310[0][0]
# __________________________________________________________________________________________________
# batch_normalization_227 (BatchN (None, 128, 128, 256 1024        conv2d_233[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_311 (LeakyReLU)     (None, 128, 128, 256 0           batch_normalization_227[0][0]
# __________________________________________________________________________________________________
# add_84 (Add)                    (None, 128, 128, 256 0           leaky_re_lu_309[0][0]
#                                                                  leaky_re_lu_311[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_312 (LeakyReLU)     (None, 128, 128, 256 0           add_84[0][0]
# __________________________________________________________________________________________________
# conv2d_234 (Conv2D)             (None, 128, 128, 128 295040      leaky_re_lu_312[0][0]
# __________________________________________________________________________________________________
# batch_normalization_228 (BatchN (None, 128, 128, 128 512         conv2d_234[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_313 (LeakyReLU)     (None, 128, 128, 128 0           batch_normalization_228[0][0]
# __________________________________________________________________________________________________
# conv2d_235 (Conv2D)             (None, 128, 128, 256 295168      leaky_re_lu_313[0][0]
# __________________________________________________________________________________________________
# batch_normalization_229 (BatchN (None, 128, 128, 256 1024        conv2d_235[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_314 (LeakyReLU)     (None, 128, 128, 256 0           batch_normalization_229[0][0]
# __________________________________________________________________________________________________
# add_85 (Add)                    (None, 128, 128, 256 0           leaky_re_lu_312[0][0]
#                                                                  leaky_re_lu_314[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_315 (LeakyReLU)     (None, 128, 128, 256 0           add_85[0][0]
# __________________________________________________________________________________________________
# conv2d_236 (Conv2D)             (None, 128, 128, 128 295040      leaky_re_lu_315[0][0]
# __________________________________________________________________________________________________
# batch_normalization_230 (BatchN (None, 128, 128, 128 512         conv2d_236[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_316 (LeakyReLU)     (None, 128, 128, 128 0           batch_normalization_230[0][0]
# __________________________________________________________________________________________________
# conv2d_237 (Conv2D)             (None, 128, 128, 256 295168      leaky_re_lu_316[0][0]
# __________________________________________________________________________________________________
# batch_normalization_231 (BatchN (None, 128, 128, 256 1024        conv2d_237[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_317 (LeakyReLU)     (None, 128, 128, 256 0           batch_normalization_231[0][0]
# __________________________________________________________________________________________________
# add_86 (Add)                    (None, 128, 128, 256 0           leaky_re_lu_315[0][0]
#                                                                  leaky_re_lu_317[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_318 (LeakyReLU)     (None, 128, 128, 256 0           add_86[0][0]
# __________________________________________________________________________________________________
# conv2d_238 (Conv2D)             (None, 128, 128, 128 295040      leaky_re_lu_318[0][0]
# __________________________________________________________________________________________________
# batch_normalization_232 (BatchN (None, 128, 128, 128 512         conv2d_238[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_319 (LeakyReLU)     (None, 128, 128, 128 0           batch_normalization_232[0][0]
# __________________________________________________________________________________________________
# conv2d_239 (Conv2D)             (None, 128, 128, 256 295168      leaky_re_lu_319[0][0]
# __________________________________________________________________________________________________
# batch_normalization_233 (BatchN (None, 128, 128, 256 1024        conv2d_239[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_320 (LeakyReLU)     (None, 128, 128, 256 0           batch_normalization_233[0][0]
# __________________________________________________________________________________________________
# add_87 (Add)                    (None, 128, 128, 256 0           leaky_re_lu_318[0][0]
#                                                                  leaky_re_lu_320[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_321 (LeakyReLU)     (None, 128, 128, 256 0           add_87[0][0]
# __________________________________________________________________________________________________
# conv2d_240 (Conv2D)             (None, 128, 128, 128 295040      leaky_re_lu_321[0][0]
# __________________________________________________________________________________________________
# batch_normalization_234 (BatchN (None, 128, 128, 128 512         conv2d_240[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_322 (LeakyReLU)     (None, 128, 128, 128 0           batch_normalization_234[0][0]
# __________________________________________________________________________________________________
# conv2d_241 (Conv2D)             (None, 128, 128, 256 295168      leaky_re_lu_322[0][0]
# __________________________________________________________________________________________________
# batch_normalization_235 (BatchN (None, 128, 128, 256 1024        conv2d_241[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_323 (LeakyReLU)     (None, 128, 128, 256 0           batch_normalization_235[0][0]
# __________________________________________________________________________________________________
# add_88 (Add)                    (None, 128, 128, 256 0           leaky_re_lu_321[0][0]
#                                                                  leaky_re_lu_323[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_324 (LeakyReLU)     (None, 128, 128, 256 0           add_88[0][0]
# __________________________________________________________________________________________________
# conv2d_242 (Conv2D)             (None, 128, 128, 128 295040      leaky_re_lu_324[0][0]
# __________________________________________________________________________________________________
# batch_normalization_236 (BatchN (None, 128, 128, 128 512         conv2d_242[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_325 (LeakyReLU)     (None, 128, 128, 128 0           batch_normalization_236[0][0]
# __________________________________________________________________________________________________
# conv2d_243 (Conv2D)             (None, 128, 128, 256 295168      leaky_re_lu_325[0][0]
# __________________________________________________________________________________________________
# batch_normalization_237 (BatchN (None, 128, 128, 256 1024        conv2d_243[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_326 (LeakyReLU)     (None, 128, 128, 256 0           batch_normalization_237[0][0]
# __________________________________________________________________________________________________
# add_89 (Add)                    (None, 128, 128, 256 0           leaky_re_lu_324[0][0]
#                                                                  leaky_re_lu_326[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_327 (LeakyReLU)     (None, 128, 128, 256 0           add_89[0][0]
# __________________________________________________________________________________________________
# conv2d_244 (Conv2D)             (None, 128, 128, 128 295040      leaky_re_lu_327[0][0]
# __________________________________________________________________________________________________
# batch_normalization_238 (BatchN (None, 128, 128, 128 512         conv2d_244[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_328 (LeakyReLU)     (None, 128, 128, 128 0           batch_normalization_238[0][0]
# __________________________________________________________________________________________________
# conv2d_245 (Conv2D)             (None, 128, 128, 256 295168      leaky_re_lu_328[0][0]
# __________________________________________________________________________________________________
# batch_normalization_239 (BatchN (None, 128, 128, 256 1024        conv2d_245[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_329 (LeakyReLU)     (None, 128, 128, 256 0           batch_normalization_239[0][0]
# __________________________________________________________________________________________________
# add_90 (Add)                    (None, 128, 128, 256 0           leaky_re_lu_327[0][0]
#                                                                  leaky_re_lu_329[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_330 (LeakyReLU)     (None, 128, 128, 256 0           add_90[0][0]
# __________________________________________________________________________________________________
# conv2d_246 (Conv2D)             (None, 128, 128, 128 295040      leaky_re_lu_330[0][0]
# __________________________________________________________________________________________________
# batch_normalization_240 (BatchN (None, 128, 128, 128 512         conv2d_246[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_331 (LeakyReLU)     (None, 128, 128, 128 0           batch_normalization_240[0][0]
# __________________________________________________________________________________________________
# conv2d_247 (Conv2D)             (None, 128, 128, 256 295168      leaky_re_lu_331[0][0]
# __________________________________________________________________________________________________
# batch_normalization_241 (BatchN (None, 128, 128, 256 1024        conv2d_247[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_332 (LeakyReLU)     (None, 128, 128, 256 0           batch_normalization_241[0][0]
# __________________________________________________________________________________________________
# add_91 (Add)                    (None, 128, 128, 256 0           leaky_re_lu_330[0][0]
#                                                                  leaky_re_lu_332[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_333 (LeakyReLU)     (None, 128, 128, 256 0           add_91[0][0]
# __________________________________________________________________________________________________
# conv2d_248 (Conv2D)             (None, 64, 64, 512)  1180160     leaky_re_lu_333[0][0]
# __________________________________________________________________________________________________
# batch_normalization_242 (BatchN (None, 64, 64, 512)  2048        conv2d_248[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_334 (LeakyReLU)     (None, 64, 64, 512)  0           batch_normalization_242[0][0]
# __________________________________________________________________________________________________
# conv2d_249 (Conv2D)             (None, 64, 64, 256)  1179904     leaky_re_lu_334[0][0]
# __________________________________________________________________________________________________
# batch_normalization_243 (BatchN (None, 64, 64, 256)  1024        conv2d_249[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_335 (LeakyReLU)     (None, 64, 64, 256)  0           batch_normalization_243[0][0]
# __________________________________________________________________________________________________
# conv2d_250 (Conv2D)             (None, 64, 64, 512)  1180160     leaky_re_lu_335[0][0]
# __________________________________________________________________________________________________
# batch_normalization_244 (BatchN (None, 64, 64, 512)  2048        conv2d_250[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_336 (LeakyReLU)     (None, 64, 64, 512)  0           batch_normalization_244[0][0]
# __________________________________________________________________________________________________
# add_92 (Add)                    (None, 64, 64, 512)  0           leaky_re_lu_334[0][0]
#                                                                  leaky_re_lu_336[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_337 (LeakyReLU)     (None, 64, 64, 512)  0           add_92[0][0]
# __________________________________________________________________________________________________
# conv2d_251 (Conv2D)             (None, 64, 64, 256)  1179904     leaky_re_lu_337[0][0]
# __________________________________________________________________________________________________
# batch_normalization_245 (BatchN (None, 64, 64, 256)  1024        conv2d_251[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_338 (LeakyReLU)     (None, 64, 64, 256)  0           batch_normalization_245[0][0]
# __________________________________________________________________________________________________
# conv2d_252 (Conv2D)             (None, 64, 64, 512)  1180160     leaky_re_lu_338[0][0]
# __________________________________________________________________________________________________
# batch_normalization_246 (BatchN (None, 64, 64, 512)  2048        conv2d_252[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_339 (LeakyReLU)     (None, 64, 64, 512)  0           batch_normalization_246[0][0]
# __________________________________________________________________________________________________
# add_93 (Add)                    (None, 64, 64, 512)  0           leaky_re_lu_337[0][0]
#                                                                  leaky_re_lu_339[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_340 (LeakyReLU)     (None, 64, 64, 512)  0           add_93[0][0]
# __________________________________________________________________________________________________
# conv2d_253 (Conv2D)             (None, 64, 64, 256)  1179904     leaky_re_lu_340[0][0]
# __________________________________________________________________________________________________
# batch_normalization_247 (BatchN (None, 64, 64, 256)  1024        conv2d_253[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_341 (LeakyReLU)     (None, 64, 64, 256)  0           batch_normalization_247[0][0]
# __________________________________________________________________________________________________
# conv2d_254 (Conv2D)             (None, 64, 64, 512)  1180160     leaky_re_lu_341[0][0]
# __________________________________________________________________________________________________
# batch_normalization_248 (BatchN (None, 64, 64, 512)  2048        conv2d_254[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_342 (LeakyReLU)     (None, 64, 64, 512)  0           batch_normalization_248[0][0]
# __________________________________________________________________________________________________
# add_94 (Add)                    (None, 64, 64, 512)  0           leaky_re_lu_340[0][0]
#                                                                  leaky_re_lu_342[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_343 (LeakyReLU)     (None, 64, 64, 512)  0           add_94[0][0]
# __________________________________________________________________________________________________
# conv2d_255 (Conv2D)             (None, 64, 64, 256)  1179904     leaky_re_lu_343[0][0]
# __________________________________________________________________________________________________
# batch_normalization_249 (BatchN (None, 64, 64, 256)  1024        conv2d_255[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_344 (LeakyReLU)     (None, 64, 64, 256)  0           batch_normalization_249[0][0]
# __________________________________________________________________________________________________
# conv2d_256 (Conv2D)             (None, 64, 64, 512)  1180160     leaky_re_lu_344[0][0]
# __________________________________________________________________________________________________
# batch_normalization_250 (BatchN (None, 64, 64, 512)  2048        conv2d_256[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_345 (LeakyReLU)     (None, 64, 64, 512)  0           batch_normalization_250[0][0]
# __________________________________________________________________________________________________
# add_95 (Add)                    (None, 64, 64, 512)  0           leaky_re_lu_343[0][0]
#                                                                  leaky_re_lu_345[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_346 (LeakyReLU)     (None, 64, 64, 512)  0           add_95[0][0]
# __________________________________________________________________________________________________
# conv2d_257 (Conv2D)             (None, 64, 64, 256)  1179904     leaky_re_lu_346[0][0]
# __________________________________________________________________________________________________
# batch_normalization_251 (BatchN (None, 64, 64, 256)  1024        conv2d_257[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_347 (LeakyReLU)     (None, 64, 64, 256)  0           batch_normalization_251[0][0]
# __________________________________________________________________________________________________
# conv2d_258 (Conv2D)             (None, 64, 64, 512)  1180160     leaky_re_lu_347[0][0]
# __________________________________________________________________________________________________
# batch_normalization_252 (BatchN (None, 64, 64, 512)  2048        conv2d_258[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_348 (LeakyReLU)     (None, 64, 64, 512)  0           batch_normalization_252[0][0]
# __________________________________________________________________________________________________
# add_96 (Add)                    (None, 64, 64, 512)  0           leaky_re_lu_346[0][0]
#                                                                  leaky_re_lu_348[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_349 (LeakyReLU)     (None, 64, 64, 512)  0           add_96[0][0]
# __________________________________________________________________________________________________
# conv2d_259 (Conv2D)             (None, 64, 64, 256)  1179904     leaky_re_lu_349[0][0]
# __________________________________________________________________________________________________
# batch_normalization_253 (BatchN (None, 64, 64, 256)  1024        conv2d_259[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_350 (LeakyReLU)     (None, 64, 64, 256)  0           batch_normalization_253[0][0]
# __________________________________________________________________________________________________
# conv2d_260 (Conv2D)             (None, 64, 64, 512)  1180160     leaky_re_lu_350[0][0]
# __________________________________________________________________________________________________
# batch_normalization_254 (BatchN (None, 64, 64, 512)  2048        conv2d_260[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_351 (LeakyReLU)     (None, 64, 64, 512)  0           batch_normalization_254[0][0]
# __________________________________________________________________________________________________
# add_97 (Add)                    (None, 64, 64, 512)  0           leaky_re_lu_349[0][0]
#                                                                  leaky_re_lu_351[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_352 (LeakyReLU)     (None, 64, 64, 512)  0           add_97[0][0]
# __________________________________________________________________________________________________
# conv2d_261 (Conv2D)             (None, 64, 64, 256)  1179904     leaky_re_lu_352[0][0]
# __________________________________________________________________________________________________
# batch_normalization_255 (BatchN (None, 64, 64, 256)  1024        conv2d_261[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_353 (LeakyReLU)     (None, 64, 64, 256)  0           batch_normalization_255[0][0]
# __________________________________________________________________________________________________
# conv2d_262 (Conv2D)             (None, 64, 64, 512)  1180160     leaky_re_lu_353[0][0]
# __________________________________________________________________________________________________
# batch_normalization_256 (BatchN (None, 64, 64, 512)  2048        conv2d_262[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_354 (LeakyReLU)     (None, 64, 64, 512)  0           batch_normalization_256[0][0]
# __________________________________________________________________________________________________
# add_98 (Add)                    (None, 64, 64, 512)  0           leaky_re_lu_352[0][0]
#                                                                  leaky_re_lu_354[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_355 (LeakyReLU)     (None, 64, 64, 512)  0           add_98[0][0]
# __________________________________________________________________________________________________
# conv2d_263 (Conv2D)             (None, 64, 64, 256)  1179904     leaky_re_lu_355[0][0]
# __________________________________________________________________________________________________
# batch_normalization_257 (BatchN (None, 64, 64, 256)  1024        conv2d_263[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_356 (LeakyReLU)     (None, 64, 64, 256)  0           batch_normalization_257[0][0]
# __________________________________________________________________________________________________
# conv2d_264 (Conv2D)             (None, 64, 64, 512)  1180160     leaky_re_lu_356[0][0]
# __________________________________________________________________________________________________
# batch_normalization_258 (BatchN (None, 64, 64, 512)  2048        conv2d_264[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_357 (LeakyReLU)     (None, 64, 64, 512)  0           batch_normalization_258[0][0]
# __________________________________________________________________________________________________
# add_99 (Add)                    (None, 64, 64, 512)  0           leaky_re_lu_355[0][0]
#                                                                  leaky_re_lu_357[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_358 (LeakyReLU)     (None, 64, 64, 512)  0           add_99[0][0]
# __________________________________________________________________________________________________
# conv2d_265 (Conv2D)             (None, 32, 32, 1024) 4719616     leaky_re_lu_358[0][0]
# __________________________________________________________________________________________________
# batch_normalization_259 (BatchN (None, 32, 32, 1024) 4096        conv2d_265[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_359 (LeakyReLU)     (None, 32, 32, 1024) 0           batch_normalization_259[0][0]
# __________________________________________________________________________________________________
# conv2d_266 (Conv2D)             (None, 32, 32, 512)  4719104     leaky_re_lu_359[0][0]
# __________________________________________________________________________________________________
# batch_normalization_260 (BatchN (None, 32, 32, 512)  2048        conv2d_266[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_360 (LeakyReLU)     (None, 32, 32, 512)  0           batch_normalization_260[0][0]
# __________________________________________________________________________________________________
# conv2d_267 (Conv2D)             (None, 32, 32, 1024) 4719616     leaky_re_lu_360[0][0]
# __________________________________________________________________________________________________
# batch_normalization_261 (BatchN (None, 32, 32, 1024) 4096        conv2d_267[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_361 (LeakyReLU)     (None, 32, 32, 1024) 0           batch_normalization_261[0][0]
# __________________________________________________________________________________________________
# add_100 (Add)                   (None, 32, 32, 1024) 0           leaky_re_lu_359[0][0]
#                                                                  leaky_re_lu_361[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_362 (LeakyReLU)     (None, 32, 32, 1024) 0           add_100[0][0]
# __________________________________________________________________________________________________
# conv2d_268 (Conv2D)             (None, 32, 32, 512)  4719104     leaky_re_lu_362[0][0]
# __________________________________________________________________________________________________
# batch_normalization_262 (BatchN (None, 32, 32, 512)  2048        conv2d_268[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_363 (LeakyReLU)     (None, 32, 32, 512)  0           batch_normalization_262[0][0]
# __________________________________________________________________________________________________
# conv2d_269 (Conv2D)             (None, 32, 32, 1024) 4719616     leaky_re_lu_363[0][0]
# __________________________________________________________________________________________________
# batch_normalization_263 (BatchN (None, 32, 32, 1024) 4096        conv2d_269[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_364 (LeakyReLU)     (None, 32, 32, 1024) 0           batch_normalization_263[0][0]
# __________________________________________________________________________________________________
# add_101 (Add)                   (None, 32, 32, 1024) 0           leaky_re_lu_362[0][0]
#                                                                  leaky_re_lu_364[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_365 (LeakyReLU)     (None, 32, 32, 1024) 0           add_101[0][0]
# __________________________________________________________________________________________________
# conv2d_270 (Conv2D)             (None, 32, 32, 512)  4719104     leaky_re_lu_365[0][0]
# __________________________________________________________________________________________________
# batch_normalization_264 (BatchN (None, 32, 32, 512)  2048        conv2d_270[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_366 (LeakyReLU)     (None, 32, 32, 512)  0           batch_normalization_264[0][0]
# __________________________________________________________________________________________________
# conv2d_271 (Conv2D)             (None, 32, 32, 1024) 4719616     leaky_re_lu_366[0][0]
# __________________________________________________________________________________________________
# batch_normalization_265 (BatchN (None, 32, 32, 1024) 4096        conv2d_271[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_367 (LeakyReLU)     (None, 32, 32, 1024) 0           batch_normalization_265[0][0]
# __________________________________________________________________________________________________
# add_102 (Add)                   (None, 32, 32, 1024) 0           leaky_re_lu_365[0][0]
#                                                                  leaky_re_lu_367[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_368 (LeakyReLU)     (None, 32, 32, 1024) 0           add_102[0][0]
# __________________________________________________________________________________________________
# conv2d_272 (Conv2D)             (None, 32, 32, 512)  4719104     leaky_re_lu_368[0][0]
# __________________________________________________________________________________________________
# batch_normalization_266 (BatchN (None, 32, 32, 512)  2048        conv2d_272[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_369 (LeakyReLU)     (None, 32, 32, 512)  0           batch_normalization_266[0][0]
# __________________________________________________________________________________________________
# conv2d_273 (Conv2D)             (None, 32, 32, 1024) 4719616     leaky_re_lu_369[0][0]
# __________________________________________________________________________________________________
# batch_normalization_267 (BatchN (None, 32, 32, 1024) 4096        conv2d_273[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_370 (LeakyReLU)     (None, 32, 32, 1024) 0           batch_normalization_267[0][0]
# __________________________________________________________________________________________________
# add_103 (Add)                   (None, 32, 32, 1024) 0           leaky_re_lu_368[0][0]
#                                                                  leaky_re_lu_370[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_371 (LeakyReLU)     (None, 32, 32, 1024) 0           add_103[0][0]
# __________________________________________________________________________________________________
# conv2d_274 (Conv2D)             (None, 32, 32, 512)  4719104     leaky_re_lu_371[0][0]
# __________________________________________________________________________________________________
# batch_normalization_268 (BatchN (None, 32, 32, 512)  2048        conv2d_274[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_372 (LeakyReLU)     (None, 32, 32, 512)  0           batch_normalization_268[0][0]
# __________________________________________________________________________________________________
# conv2d_275 (Conv2D)             (None, 32, 32, 256)  1179904     leaky_re_lu_372[0][0]
# __________________________________________________________________________________________________
# batch_normalization_269 (BatchN (None, 32, 32, 256)  1024        conv2d_275[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_373 (LeakyReLU)     (None, 32, 32, 256)  0           batch_normalization_269[0][0]
# __________________________________________________________________________________________________
# conv2d_276 (Conv2D)             (None, 32, 32, 128)  295040      leaky_re_lu_373[0][0]
# __________________________________________________________________________________________________
# batch_normalization_270 (BatchN (None, 32, 32, 128)  512         conv2d_276[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_374 (LeakyReLU)     (None, 32, 32, 128)  0           batch_normalization_270[0][0]
# __________________________________________________________________________________________________
# conv2d_277 (Conv2D)             (None, 32, 32, 10)   1290        leaky_re_lu_374[0][0]
# ==================================================================================================
# Total params: 74,285,194
# Trainable params: 74,247,498
# Non-trainable params: 37,696
# __________________________________________________________________________________________________
